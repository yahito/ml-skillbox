# %% [markdown]
# # Домашнее задание
#
# В этом домашнем задании вам предстоит обучить DCGAN для генерации лиц и изучить латентное пространство. Модель DCGAN аналогична той, которая использовалась на лекции. Рекомендуем вам подробно ознакомится с приведенным кодом, чтобы лучше понимать как все устроено “изнутри”.
#
#
# В качестве напоминания приводим ниже иллюстрацию архитектуры ([источник](https://github.com/znxlwm/tensorflow-MNIST-GAN-DCGAN) иллюстрации).
#
# ![alt text](https://github.com/znxlwm/tensorflow-MNIST-GAN-DCGAN/raw/master/tensorflow_DCGAN.png)

# %%
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import time
from IPython import display
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.layers import UpSampling2D, Conv2D, BatchNormalization, LeakyReLU, Conv2DTranspose, Reshape, Flatten


cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
init = RandomNormal(mean=0.0, stddev=0.02)
# Out:
# 2023-07-19 19:30:37.404773: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-19 19:30:37.542761: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 19:30:38.229083: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
# модель незначительно отличается от представленной на лекции
# добавлено сохранение весов, восстановление обучения, немного упрощен код

class DCGAN(tf.keras.Model):
    def __init__(self, image_size, output_path, num_channels=1, z_dim=150,
                 G_h_size=128, D_h_size=128):
        """
        image_size -- размер стороны квадратной картинки
        output_path -- путь для сохранения артефактов обучения. в корне -- картинки с разных итераций, в папке model -- модель
        num_channels -- количество каналов изображения
        z_dim -- размерность латентного вектора
        G_h_size -- минимальный размер фильтров с сверточных слоях генератора
        D_h_size -- минимальный размер фильтров с сверточных слоях дискриминатора
        """
        super().__init__()
        self.image_size = image_size
        self.num_channels = num_channels
        self.z_dim = z_dim

        self.multiply = int(np.log2(self.image_size / 8)) # столько раз нужно применить апсемплинг или даунсемплинг
                                                          # чтобы из (4,4) получить (image_size/2, image_size/2) и наоборот

        self.output_path =  Path(output_path)
        (self.output_path / "model").mkdir(exist_ok=True)

        self.G_h_size = G_h_size
        self.D_h_size = D_h_size

        self.generator = self._build_generator()
        self.discriminator = self._build_discriminator()

        self.gen_optimizer = tf.keras.optimizers.legacy.Adam(2e-4, beta_1=0.5, beta_2=0.9)
        self.dis_optimizer = tf.keras.optimizers.legacy.Adam(2e-4, beta_1=0.5, beta_2=0.9)

        self.gen_loss_hist = []
        self.disc_loss_hist = []
        self._vis_h = 5
        self._vis_w = 5
        self._vis_noise = np.random.normal(0, 1, (self._vis_h* self._vis_w, self.z_dim)).astype(np.float32)
        self.start_iteration = 0

        self.load_weights(str(self.output_path / "model" / "dcgan_model"))

    def discriminator_loss(self, real_output, fake_output, gp):
        return  tf.math.reduce_mean(fake_output) -  tf.math.reduce_mean(real_output) + 10 * gp

    def generator_loss(self, fake_output):
        return -1. * tf.math.reduce_mean(fake_output)

    def gradient_penalty(self, real, fake, eps):
        int_images = real * eps + fake * (1 - eps)

        with tf.GradientTape() as tape:
            tape.watch(int_images)
            scores = self.discriminator(int_images)

        gradient = tape.gradient(scores, int_images)[0]
        gradient_norm = tf.norm(gradient)
        gp = tf.math.reduce_mean((gradient_norm - 1)**2)
        return gp
    
    def _conv_bn_leaky(self, kernel_size, channels, stride=1):
        """
        Этот блок мы будем часто использовать -- поэтому вынесем его в отдельную функцию

        Он содержит Conv + BatchNorm + LeakyReLU

        При указании stride=2 -- уменьшит размер в два раза.
        """
        model = tf.keras.Sequential()
        model.add(Conv2D(channels,
                         kernel_size=kernel_size, padding="same",
                         use_bias=False, kernel_initializer=init,
                         strides=(stride, stride))) # use_bias=False, т.к. BatchNorm и так вычтет среднее
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        return model


    def _build_generator(self):
        """
        Генератор должен превращать вектор длины self.z_dim в
        картинку image_size x image_size x num_channels

        """

        model = tf.keras.Sequential()
        # для начала сделаем вектор -- трехмерным тензором м помощью Reshape
        model.add(Reshape((1, 1, self.z_dim), input_shape=(self.z_dim,)))

        # Превратим его в тензор размера (4, 4, self.G_h_size * 2**self.multiply)
        model.add(Conv2DTranspose(self.G_h_size * 2**self.multiply,
                                  kernel_size=4, use_bias=False,
                                  kernel_initializer=init))
        model.add(BatchNormalization())
        model.add(LeakyReLU())


        for i in range(self.multiply):
            model.add(UpSampling2D()) # увеличиваем картинку
            model.add(self._conv_bn_leaky(4, self.G_h_size * 2**self.multiply // 2**(i+1))) # уменьшаем количество фильтров в два раза

        assert model.output_shape[1:] == (self.image_size // 2, self.image_size // 2, self.D_h_size), f"{model.output_shape, self.D_h_size}"

        model.add(UpSampling2D())
        model.add(Conv2D(self.num_channels,
                         kernel_size=4, strides=(1, 1),
                         activation="tanh", padding="same",
                         kernel_initializer=init))
        return model

    def _build_discriminator(self):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.InputLayer(
            input_shape=((self.image_size, self.image_size, self.num_channels))))
        model.add(self._conv_bn_leaky(kernel_size=4,
                                      channels=self.D_h_size,
                                      stride=2,
                                      ))

        for i in range(self.multiply):
            model.add(self._conv_bn_leaky(kernel_size=4,
                                          channels=self.D_h_size * (2 ** (i+1)),
                                          stride=2)) # количество фильтров увеличивается, размер уменьшается
        assert model.output_shape[1:] == (4, 4, self.D_h_size * 2**self.multiply), f"{model.output_shape}"
        model.add(Conv2D(1, kernel_size=4, kernel_initializer=init, use_bias=False)) # без активации !
        model.add(Flatten())
        return model

    def train_step(self, images):

        if (len(images) != BATCH_SIZE):
            return
        """
        Шаг обучения как в прошлом уроке
        """
        noise = tf.random.normal([tf.cast(images.shape[0], tf.int32), self.z_dim])

        for i in range(0, 5):
            with tf.GradientTape() as d_tape:
                generated_images = self.generator(noise, training=True)
    
                real_output = self.discriminator(images, training=True)
                fake_output = self.discriminator(generated_images, training=True)
    
                ep = tf.random.normal([BATCH_SIZE, 1, 1, 1], 0.0, 1.0)
    
                gp = self.gradient_penalty(images, generated_images, ep)
                disc_loss = self.discriminator_loss(real_output, fake_output, gp)
        
            gradients_of_discriminator = d_tape.gradient(disc_loss, self.discriminator.trainable_variables)
            self.dis_optimizer.apply_gradients(zip(gradients_of_discriminator, self.discriminator.trainable_variables))

        with tf.GradientTape() as g_tape:
            generated_images = self.generator(noise, training=True)
            fake_output = self.discriminator(generated_images, training=True)
            g_loss = self.generator_loss(fake_output)
            
        gradients_of_generator = g_tape.gradient(g_loss, self.generator.trainable_variables)
        self.gen_optimizer.apply_gradients(zip(gradients_of_generator, self.generator.trainable_variables))
        
        return g_loss, disc_loss

    def save_imgs(self, epoch):
        """
        Сохранение промежуточных картинок на диск
        """
        gen_imgs = self.generator(self._vis_noise, training=False)
        gen_imgs = 0.5 * gen_imgs + 0.5
        fig, axs = plt.subplots(self._vis_h, self._vis_w, figsize=(6,6))
        cnt = 0
        for i in range(self._vis_h):
            for j in range(self._vis_w):
                if self.num_channels == 1:
                    axs[i, j].imshow(gen_imgs[cnt, :, :, 0], cmap='gray')
                else:
                    axs[i, j].imshow(gen_imgs[cnt, :, :, :])
                axs[i, j].axis('off')
                cnt += 1
        fig.savefig(self.output_path / f"{epoch}.png")
        plt.show()

    def train(self, dataset, num_iters=2000, show_every=25):
        """
        Цикл обучения
        """
        start = time.time()
        iters = self.start_iteration
        for image_batch in dataset:

            if len(image_batch) != BATCH_SIZE:
                continue
                
            print(".", end='')
            gen_loss, disc_loss = self.train_step(image_batch)

            self.disc_loss_hist.append(disc_loss.numpy())
            self.gen_loss_hist.append(gen_loss.numpy())

            if iters % show_every == 0:
                display.clear_output(wait=True)
                plt.figure()
                plt.plot(self.disc_loss_hist, label="Discriminator loss")
                plt.plot(self.gen_loss_hist, label="Generator loss")
                plt.legend(loc="best")
                plt.figure()
                self.save_imgs(f"{iters}")
                self.save_weights(str(self.output_path / "model" / "dcgan_model"), save_format='tf')

                print(f"\n{iters}/{num_iters}")
                print(f'Time elapsed from start {time.time() - start} sec')

            iters += 1
            if iters > num_iters:
                print(f'Finished. Time elapsed from start {time.time() - start} sec')
                return

# %% [markdown]
# ## Загрузка датасета

# %%
! pip install gdown
import gdown

url = 'https://drive.google.com/uc?id=0BxYys69jI14kYVM3aVhKS1VhRUk'
output = '/tmp/UTKFace.tar.gz'
gdown.download(url, output, quiet=False)
# !mkdir  /tmp/faces
! tar -xzf /tmp/UTKFace.tar.gz -C /tmp/faces
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: gdown in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (4.7.1)
# Requirement already satisfied: filelock in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from requests[socks]->gdown) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from requests[socks]->gdown) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/yahito/miniconda3/envs/tf-2-2/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=0BxYys69jI14kYVM3aVhKS1VhRUk
# From (redirected): https://drive.google.com/uc?id=0BxYys69jI14kYVM3aVhKS1VhRUk&confirm=t&uuid=99e053db-d6b1-49e1-bea9-09c466db4303
# To: /tmp/UTKFace.tar.gz
# 100%|████████████████████████████████████████████████████████████████████████████████| 107M/107M [00:08<00:00, 12.3MB/s]

# %% [markdown]
# ## Задание 1. Создание генераторов данных
#
# Реализуйте генератор изображений с указанными ниже BATCH_SIZE и IMAGE_SIZE. Используйте для этого ImageDataGenerator, flow_from_dataframe или flow_from_directory. Данные расположены в папке "/tmp/UTKFace". Классы в этом задании нам не нужны.
#
# *Интенсивности картинок должны быть нормализованы от -1 до 1.*

# %%
BATCH_SIZE = 128
IMAGE_SIZE = 64

# %%
import os
os.listdir("/tmp/faces/")
# Out:
# ['UTKFace']

# %%
# < YOUR CODE STARTS HERE >
# image_generator -- должен содержать необходимый генератор
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def preprocess_input_facenet(image):
    print(type(image))
    return image


datagen = ImageDataGenerator(preprocessing_function=lambda x: (x/127.5) - 1)  # fraction of images reserved for validation

image_generator = datagen.flow_from_directory(
    '/tmp/faces',
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode=None)  # set as training data



# < YOUR CODE ENDS HERE >
# Out:
# Found 23708 images belonging to 1 classes.

# %%
sample = next(image_generator)
assert sample.shape == (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3), f"Размер батча должен быть: {(BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3)}.  Получен {sample.shape}"
print("Shape test passed")
# если препроцессинг правильный, то картинка ниже имеет реалистичные цвета и matplotlib не ругается
plt.imshow((sample[0] + 1.) / 2)
# Out:
# Shape test passed
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-2.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-2.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-2.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-2.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-2.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-3.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-3.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-3.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-3.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-3.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-4.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-4.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-4.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-4.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).generator.layer_with_weights-4.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-0.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-0.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-0.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-0.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-0.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-1.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-1.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-1.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-1.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-1.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-2.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-2.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-2.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-2.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-2.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-3.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-3.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-3.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-3.layer_with_weights-1.moving_mean
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).discriminator.layer_with_weights-3.layer_with_weights-1.moving_variance
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-5.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-5.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-2.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-2.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-2.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-3.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-3.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-3.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-4.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-4.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'm' for (root).generator.layer_with_weights-4.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-5.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-5.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-2.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-2.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-2.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-3.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-3.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-3.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-4.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-4.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).gen_optimizer's state 'v' for (root).generator.layer_with_weights-4.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-4.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-0.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-0.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-0.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-1.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-1.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-1.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-2.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-2.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-2.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-3.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-3.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'm' for (root).discriminator.layer_with_weights-3.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-4.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-0.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-0.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-0.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-1.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-1.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-1.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-2.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-2.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-2.layer_with_weights-1.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-3.layer_with_weights-0.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-3.layer_with_weights-1.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).dis_optimizer's state 'v' for (root).discriminator.layer_with_weights-3.layer_with_weights-1.beta

# %% [markdown]
# ## Задание 2. Обучение DCGAN
#
# В этом задании вам нужно просто запустить обучение GAN. С указанными параметрами оно займет около часа.
#
# Предварительно заманутите Google Drive, для сохранения промежуточных результатов и весов модели.

# %%
output = Path("/home/yahito/Projects/ipyn-wc/")
output.mkdir(exist_ok=True)
(output / "model").mkdir(exist_ok=True)

gan = DCGAN(image_size=IMAGE_SIZE, num_channels=3, output_path=output,
           z_dim=150, D_h_size=128, G_h_size=128)

# %%
# если при запуске обучения вы видите "WARNING:tensorflow:Entity <bound method DCGAN.train_step ...",
# раскомментируйте строчку ниже, установите пакет и рестартните runtime
# это временный баг в tf из-за изменения версии gast
#! pip install 'gast==0.2.2'

# %%
images = list(output.glob("*.png"))
if images: # если папка не пуста, то продолжим обучение с последней итерации
    iters = list(map(lambda x: int(x.name.split(".")[0]), images))
    last_iter = sorted(iters)[-1]
    gan.start_iteration = last_iter
    print(f"Resuming model from {last_iter} iteration")

gan.train(image_generator, 10000, 50)
# Out:
# 2350/10000
# Time elapsed from start 72.63571166992188 sec
# ..............
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_533/2031935150.py in ?()
#       4     last_iter = sorted(iters)[-1]
#       5     gan.start_iteration = last_iter
#       6     print(f"Resuming model from {last_iter} iteration")
#       7
# ----> 8 gan.train(image_generator, 10000, 50)
#
# /tmp/ipykernel_533/159243465.py in ?(self, dataset, num_iters, show_every)
#     191             if len(image_batch) != BATCH_SIZE:
#     192                 continue
#     193
#     194             print(".", end='')
# --> 195             gen_loss, disc_loss = self.train_step(image_batch)
#     196
#     197             self.disc_loss_hist.append(disc_loss.numpy())
#     198             self.gen_loss_hist.append(gen_loss.numpy())
#
# /tmp/ipykernel_533/159243465.py in ?(self, images)
#     137         noise = tf.random.normal([tf.cast(images.shape[0], tf.int32), self.z_dim])
#     138
#     139         for i in range(0, 5):
#     140             with tf.GradientTape() as d_tape:
# --> 141                 generated_images = self.generator(noise, training=True)
#     142
#     143                 real_output = self.discriminator(images, training=True)
#     144                 fake_output = self.discriminator(generated_images, training=True)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/training.py in ?(self, *args, **kwargs)
#     554                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     555
#     556             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     557
# --> 558         return super().__call__(*args, **kwargs)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/base_layer.py in ?(self, *args, **kwargs)
#    1141
#    1142                 with autocast_variable.enable_auto_cast_variables(
#    1143                     self._compute_dtype_object
#    1144                 ):
# -> 1145                     outputs = call_fn(inputs, *args, **kwargs)
#    1146
#    1147                 if self._activity_regularizer:
#    1148                     self._handle_activity_regularization(inputs, outputs)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/sequential.py in ?(self, inputs, training, mask)
#     408
#     409         if self._graph_initialized:
#     410             if not self.built:
#     411                 self._init_graph_network(self.inputs, self.outputs)
# --> 412             return super().call(inputs, training=training, mask=mask)
#     413
#     414         outputs = inputs  # handle the corner case where self.layers is empty
#     415         for layer in self.layers:
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/functional.py in ?(self, inputs, training, mask)
#     508         Returns:
#     509             A tensor if there is a single output, or
#     510             a list of tensors if there are more than one outputs.
#     511         """
# --> 512         return self._run_internal_graph(inputs, training=training, mask=mask)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/functional.py in ?(self, inputs, training, mask)
#     665                 if any(t_id not in tensor_dict for t_id in node.flat_input_ids):
#     666                     continue  # Node is not computable, try skipping.
#     667
#     668                 args, kwargs = node.map_arguments(tensor_dict)
# --> 669                 outputs = node.layer(*args, **kwargs)
#     670
#     671                 # Update tensor_dict.
#     672                 for x_id, y in zip(
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/training.py in ?(self, *args, **kwargs)
#     554                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     555
#     556             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     557
# --> 558         return super().__call__(*args, **kwargs)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/base_layer.py in ?(self, *args, **kwargs)
#    1141
#    1142                 with autocast_variable.enable_auto_cast_variables(
#    1143                     self._compute_dtype_object
#    1144                 ):
# -> 1145                     outputs = call_fn(inputs, *args, **kwargs)
#    1146
#    1147                 if self._activity_regularizer:
#    1148                     self._handle_activity_regularization(inputs, outputs)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/sequential.py in ?(self, inputs, training, mask)
#     408
#     409         if self._graph_initialized:
#     410             if not self.built:
#     411                 self._init_graph_network(self.inputs, self.outputs)
# --> 412             return super().call(inputs, training=training, mask=mask)
#     413
#     414         outputs = inputs  # handle the corner case where self.layers is empty
#     415         for layer in self.layers:
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/functional.py in ?(self, inputs, training, mask)
#     508         Returns:
#     509             A tensor if there is a single output, or
#     510             a list of tensors if there are more than one outputs.
#     511         """
# --> 512         return self._run_internal_graph(inputs, training=training, mask=mask)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/functional.py in ?(self, inputs, training, mask)
#     665                 if any(t_id not in tensor_dict for t_id in node.flat_input_ids):
#     666                     continue  # Node is not computable, try skipping.
#     667
#     668                 args, kwargs = node.map_arguments(tensor_dict)
# --> 669                 outputs = node.layer(*args, **kwargs)
#     670
#     671                 # Update tensor_dict.
#     672                 for x_id, y in zip(
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/engine/base_layer.py in ?(self, *args, **kwargs)
#    1141
#    1142                 with autocast_variable.enable_auto_cast_variables(
#    1143                     self._compute_dtype_object
#    1144                 ):
# -> 1145                     outputs = call_fn(inputs, *args, **kwargs)
#    1146
#    1147                 if self._activity_regularizer:
#    1148                     self._handle_activity_regularization(inputs, outputs)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/utils/traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/layers/activation/leaky_relu.py in ?(self, inputs)
#      71     def call(self, inputs):
# ---> 72         return backend.relu(inputs, alpha=self.alpha)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/keras/backend.py in ?(x, alpha, max_value, threshold)
#    5375     # lists, tuples do not have 'dtype' attribute.
#    5376     dtype = getattr(x, "dtype", floatx())
#    5377     if alpha != 0.0:
#    5378         if max_value is None and threshold == 0:
# -> 5379             return tf.nn.leaky_relu(x, alpha=alpha)
#    5380
#    5381         if threshold != 0:
#    5382             negative_part = tf.nn.relu(-x + threshold)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1173
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
#    1176         return dispatch_target(*args, **kwargs)
# -> 1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179         # TypeError, when given unexpected types.  So we need to catch both.
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py in ?(features, alpha, name)
#    3689     if features.dtype.is_integer:
#    3690       features = math_ops.cast(features, dtypes.float32)
#    3691     if isinstance(alpha, np.ndarray):
#    3692       alpha = alpha.item()
# -> 3693     return gen_nn_ops.leaky_relu(features, alpha=alpha, name=name)
#
# ~/miniconda3/envs/tf-2-2/lib/python3.11/site-packages/tensorflow/python/ops/gen_nn_ops.py in ?(features, alpha, name)
#    5740         _ctx, "LeakyRelu", name, features, "alpha", alpha)
#    5741       return _result
#    5742     except _core._NotOkStatusException as e:
#    5743       _ops.raise_from_not_ok_status(e, name)
# -> 5744     except _core._FallbackException:
#    5745       pass
#    5746     try:
#    5747       return leaky_relu_eager_fallback(
#
# KeyboardInterrupt:

# %%
output = Path("/home/yahito/Projects/ipyn-wc/")
output.mkdir(exist_ok=True)
(output / "model").mkdir(exist_ok=True)
gan.save_weights(str(output), save_format='tf')

# %% [markdown]
# После того как модель обучена, можно посмотреть какие лица она научилась генерировать!

# %%
def generate_data(latent_vector, generator):
    """
    Для того чтобы сгенерировать объект нам нужен генератор и латентный вектор
    """
    gen_imgs = generator(latent_vector, training=False)
    gen_imgs = 0.5 * gen_imgs + 0.5
    return gen_imgs

# %%
v1 = tf.random.normal([1, 150]) # случайный вектор
print("Вектор: ", v1.numpy()[0, :10]) # распечатаем 10 первых элементов
img = generate_data(v1, gan.generator);
_ = plt.imshow(img[0]) # сгенерированное лицо, попробуйте сгенерировать несколько.
                                                    # они должны получаться достаточно реалистичными
print(img.shape)
print(sample.shape)
output = gan.discriminator(sample, training=False)
print(output)
# Out:
# Вектор:  [ 0.27498987 -0.40972716  0.8450913   0.49203536  1.250347   -0.07636266
#  -0.11901288 -1.2236437   1.619406   -0.6901975 ]
# (1, 64, 64, 3)
# (128, 64, 64, 3)
# tf.Tensor(
# [[-520.91016]
#  [-523.78125]
#  [-520.9237 ]
#  [-515.8463 ]
#  [-515.7668 ]
#  [-524.8767 ]
#  [-530.41095]
#  [-525.6355 ]
#  [-522.1419 ]
#  [-521.9774 ]
#  [-513.2699 ]
#  [-517.8666 ]
#  [-518.8891 ]
#  [-520.5126 ]
#  [-513.4241 ]
#  [-516.92395]
#  [-514.9062 ]
#  [-537.2433 ]
#  [-517.2892 ]
#  [-526.23126]
#  [-523.5388 ]
#  [-530.5211 ]
#  [-523.332  ]
#  [-524.4491 ]
#  [-518.3815 ]
#  [-522.922  ]
#  [-518.5646 ]
#  [-523.63306]
#  [-516.7993 ]
#  [-537.30457]
#  [-527.6255 ]
#  [-533.1925 ]
#  [-530.9657 ]
#  [-523.0164 ]
#  [-530.14685]
#  [-525.14624]
#  [-518.4897 ]
#  [-535.0769 ]
#  [-519.59204]
#  [-518.4021 ]
#  [-520.35736]
#  [-518.97925]
#  [-522.606  ]
#  [-522.61285]
#  [-521.452  ]
#  [-522.12665]
#  [-522.02576]
#  [-518.5307 ]
#  [-523.3185 ]
#  [-524.5588 ]
#  [-524.78613]
#  [-540.1864 ]
#  [-520.04224]
#  [-523.0602 ]
#  [-528.3143 ]
#  [-529.72437]
#  [-538.3165 ]
#  [-519.82306]
#  [-519.6919 ]
#  [-522.131  ]
#  [-529.4871 ]
#  [-521.79834]
#  [-540.36017]
#  [-518.61066]
#  [-522.9517 ]
#  [-520.08374]
#  [-524.0304 ]
#  [-530.1219 ]
#  [-527.07806]
#  [-522.3396 ]
#  [-517.3651 ]
#  [-520.6218 ]
#  [-524.6251 ]
#  [-524.1465 ]
#  [-525.8847 ]
#  [-520.24036]
#  [-537.8231 ]
#  [-520.9481 ]
#  [-527.48804]
#  [-514.35315]
#  [-517.18616]
#  [-527.3948 ]
#  [-530.9318 ]
#  [-526.16504]
#  [-513.90216]
#  [-532.01904]
#  [-518.18164]
#  [-526.3595 ]
#  [-521.6081 ]
#  [-513.6034 ]
#  [-513.53723]
#  [-526.2739 ]
#  [-520.8326 ]
#  [-521.21155]
#  [-518.0937 ]
#  [-522.35706]
#  [-514.38525]
#  [-515.2995 ]
#  [-527.52966]
#  [-518.9234 ]
#  [-527.8355 ]
#  [-539.5863 ]
#  [-529.104  ]
#  [-518.3743 ]
#  [-520.3334 ]
#  [-523.13403]
#  [-530.0182 ]
#  [-519.4393 ]
#  [-522.3667 ]
#  [-532.71924]
#  [-516.5073 ]
#  [-513.11273]
#  [-520.65076]
#  [-526.355  ]
#  [-514.1481 ]
#  [-526.7016 ]
#  [-522.48193]
#  [-519.7387 ]
#  [-511.30927]
#  [-515.9855 ]
#  [-556.55975]
#  [-520.5274 ]
#  [-522.76086]
#  [-521.0688 ]
#  [-520.6716 ]
#  [-515.3699 ]
#  [-518.8611 ]
#  [-527.14325]], shape=(128, 1), dtype=float32)

# %% [markdown]
# ## Задание 3. Поиск вектора улыбки
#
# В этом задании вам предстоит найти “вектор улыбки” и доказать что он таковым является.
#
# Что это означает? Как мы уже знаем, GAN генерирует данные из случайных векторов из определенного распределения. Такие вектора образуют латентное пространство. Напомню аналогию с бегунками в компьютерной игре - в этом случае латентное пространство задается всеми положениями бегунков, которым соответствуют реалистичные лица.
#
# В нашем случае GAN тоже выучил нечто подобное, ведь ему хватает 100 чисел, чтобы создать лицо -- это и есть его бегунки. Можно увидеть, что среди сгенерированных лиц имеются лица с улыбкой и без. А значит можно предположить, что какое-то определенное расположение этих бегунков (определенные значения латентного вектора) отвечают за улыбку. Тогда можно считать, что есть определенная комбинация этих 100 чисел, прибавив которую к вектору соответствующему нейтральному лицу можно получить это же лицо, только с улыбкой. Эти 100 чисел мы и называем “вектор улыбки”.

# %%
# вспомогательный код
def generate_many(generator, n):
    vis_noise = np.random.normal(0, 1, (n, 150)).astype(np.float32)
    gen_imgs = generator(vis_noise, training=False)
    show_many(gen_imgs, "Generated images")
    return vis_noise

def show_many(images, title=""):
    w = h = int(np.sqrt(len(images)))
    images = (np.clip(images, -1, 1) + 1.) / 2.

    fig, axs = plt.subplots(w, h, figsize=(w, h))
    if title != "":
        fig.suptitle(title)

    cnt = 0
    for i in range(h):
        for j in range(w):
            axs[i, j].imshow(images[cnt, :, :, :])
            axs[i, j].set_title(f"{cnt}")
            axs[i, j].axis('off')
            cnt += 1
    plt.subplots_adjust(wspace=.5)

# %% [markdown]
# ### a) Интерполяция
# Используйте функцию show_interpolation для отображения превращения лица соответствующего латентному вектору `v_1` в лицо, соответствующее `v_2`. Вектора определите случайно из правильного распределения.

# %%
def show_interpolation(v_1, v_2, generator, n=20):
    """
    Превращает v_1 в v_2 за n шагов, изображая
    картинки соответствующие промежуточным векторам

    """
    fig, axs = plt.subplots(1, n, figsize=(n,1))
    for i, alpha in enumerate(np.linspace(0, 1, n)):
        curr_vec = v_1 * (1-alpha) + v_2 * alpha
        image = generate_data(curr_vec, gan.generator)[0]
        axs[i].imshow(image)
        axs[i].axis('off')

# %%
# < YOUR CODE STARTS HERE >

vis_noise1 = np.random.normal(0, 1, (2, 150)).astype(np.float32)
vis_noise2 = np.random.normal(0, 1, (2, 150)).astype(np.float32)

# < YOUR CODE ENDS HERE >
show_interpolation(vis_noise1, vis_noise2, gan.generator)

# %% [markdown]
# ## b) Поиск вектора улыбки
#
# Придумайте каким образом найти *вектор улыбки* в латентном пространстве и докажите визуально, что это именно он -- превратив нейтрального человека в улыбающегося и наоборот.
#
# *Вам могут пригодится функции generate_many и show-interpolation*
#
# Результат должен получиться похожим на:
#
# <img alt="smile.png" src="https://sun9-51.userapi.com/c857228/v857228713/aea82/t93eL7L3zbU.jpg">
# Если затрудняетесь – ниже есть подсказка. Но обязательно сначала подумайте над задачей сами)

# %%
# < YOUR CODE STARTS HERE >

smile = [3, 7, 14, 22, 30, 33, 63, 141, 142, 143, 125, 103]

mylist = []
for i in range(0, len(smile)):
    mylist.append(faces[smile[i]])
mat = np.array(mylist)

smile_vactor = np.mean(mat, axis=0)

fig, axs = plt.subplots(1, 2, figsize=(2,1))

print(np.expand_dims(faces[0], axis=0).shape)

axs[0].imshow(generate_data(np.expand_dims(faces[34], axis=0), gan.generator)[0])
axs[0].axis('off')
axs[1].imshow(generate_data(np.expand_dims(faces[34] + smile_vactor, axis=0), gan.generator)[0])
axs[1].axis('off')
# Out:
# (1, 150)
# (-0.5, 63.5, 63.5, -0.5)

# %%
# поиск вектора улыбки
faces = generate_many(gan.generator, 150)

#smile = [3, 7, 14, 22, 30, 33, 63, 141, 142, 143, 125, 103]

# %%
smile = [3, 7, 14, 22, 42, 45, 60, 75, 92, 115]

# %%
# нейтральный человек ------> с улыбкой

# %%
# человек с улыбкой ------> нейтральный

# %%
# < YOUR CODE ENDS HERE >

# %%
#@title Подсказка (спойлер). Нажмите дважды чтобы открыть { display-mode: "form" }
"""
Для выполнения задания воспользуйтесь функцией generate_many
для того чтобы получить 100 сгенерированных изображений
и соответствующие им вектора (их вернет эта функция).

Вы увидите, что лица пронумерованы и среди них есть лица
с улыбкой. выберите около 10 лиц с улыбкой и 10 без,
запомните их номера. Затем посчитайте средний вектор
лица без улыбки и средний вектор лица с улыбкой. Разница
между ними и будет искомым вектором.
"""

# %% [markdown]
# ## Бонусное задание
#
# Есть несколько вариантов выполнения бонусного задания, оно необязательное, но поможет вам глубже погрузиться в тему:
#
# 1.  Как вы обратили внимание, мы работали с картинками очень маленького разрешения  -- 32x32. Это было сделано для ускорения вычислений. Попробуйте обучить модель 64x64. Это может занять гораздо больше времени. У авторов https://github.com/znxlwm/pytorch-MNIST-CelebA-GAN-DCGAN на обучение ушло около 4 часов. Вы можете использовать датасет, [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) использованный ими. Или https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/ .
# 2.  Проявите креатив. Обучите GAN для новых данных. Например, для генерации [мордочек кошек](https://ajolicoeur.wordpress.com/cats/) (по ссылке несколько практических рекомендаций по обучению GAN вообще и некоторые более новые архитектуры), [персонажей аниме](https://github.com/Mckinsey666/Anime-Face-Dataset) и тд. Вы можете изменять имеющийся код (делайте это ниже) или использовать сторонние реализации при обязательном цитировании источников.
